# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from numpy import genfromtxt

# %%
data = np.genfromtxt('Dados.csv', delimiter=',', skip_header=1)
x = data[:,0]
y = data[:,1]
z = data[:,2]

X = np.array(X).reshape(9,9)
Y = np.array(Y).reshape(9,9)
Z = np.array(Z).reshape(9,9)

# %%
fig, ax = plt.subplots()
ax.figure.set_size_inches(8, 8)

CS = ax.contour(X, Y, Z, 10, colors='b')
ax.clabel(CS, fontsize=18, inline=1, fmt= '%1.2f V')
ax.tick_params(labelsize=18)
ax.set_xlabel('x (cm)', size=22)
ax.set_ylabel('y (cm)', size=22)
ax.grid()

plt.show()
